# %%
import openpyxl
wb = openpyxl.load_workbook('/realestatedata.xlsx')

# %%
# Printing all the sheet names
sheets = wb.sheetnames
print(sheets)
# Out:
# ['stouffville', 'peter']

# %%
real_estate = wb['stouffville']

# %%
# Type of realestate
print(type(real_estate))
# Out:
# <class 'openpyxl.worksheet.worksheet.Worksheet'>

# %%
# Title of worksheet
print(real_estate.title)
# Out:
# stouffville

# %%
# Printing particular cell value
print("Cell value for A1")
print(real_estate['A1'].value)
# Out:
# Cell value for A1
# Type

# %%
#Range of cells
for i in range(1,8):
    print(real_estate.cell(row=i,column=10).value)
# Out:
# Sold Price
# None
# 999000
# 1000000
# 1300800
# 860000
# 950000

# %%
#Average of cells
print("Get the average")
for i in range(1,190):
    print(real_estate.cell(row=i,column=10).value)
# Out:
# Get the average
# Sold Price
# None
# 999000
# 1000000
# 1300800
# 860000
# 950000
# 881000
# 980000
# 953000
# 1380000
# 1210000
# 1151000
# None
# 998000
# None
# 1200000
# 1170000
# 902000
# None
# 950000
# 990000
# 940000
# 880000
# 1240000
# 1385000
# 1550000
# 1788000
# 1310000
# 2025000
# 955000
# None
# 950000
# 945211
# 830000
# 865000
# None
# 978900
# 997000
# None
# 1200000
# 1375000
# 850000
# None
# None
# 1015000
# 1350000
# 1219999
# 900000
# None
# 1188000
# 1282888
# None
# None
# None
# 1310000
# 1160000
# None
# 1075000
# None
# 1165000
# 1060000
# 1210000
# 1200000
# 1265000
# 1200000
# None
# None
# 1280000
# None
# None
# 1060000
# 1200000
# 1738000
# 1100000
# 1165900
# 1275000
# 1204800
# 1350000
# 1260000
# 1335000
# 1039980
# 1025000
# 1000000
# None
# 1250000
# None
# None
# 1210000
# 1270000
# 1080000
# 1322500
# None
# None
# 973069
# 925000
# 1050000
# 1500000
# 1250500
# 1370000
# 1045000
# 1135000
# 1300000
# 885000
# None
# 990000
# 1050888
# ...

# %%
for i in range(2,190):

        house = (real_estate.cell(row=i,column=10).value)
        print("Housetype:",house)
       
        Description= (real_estate.cell(row=i,column=2).value)
        print("Description:",Description)
        
        Bedroom= (real_estate.cell(row=i,column=17).value)
        print("Bedroom:",Bedroom)
        
        price= (real_estate.cell(row=i,column=10).value)
        print("Price:",price)
# Out:
# Housetype: None
# Description: 2-Storey
# Bedroom: 4
# Price: None
# Housetype: 999000
# Description: 2-Storey
# Bedroom: 3
# Price: 999000
# Housetype: 1000000
# Description: 2-Storey
# Bedroom: 3
# Price: 1000000
# Housetype: 1300800
# Description: 2-Storey
# Bedroom: 4
# Price: 1300800
# Housetype: 860000
# Description: Bungalow
# Bedroom: 3
# Price: 860000
# Housetype: 950000
# Description: 2-Storey
# Bedroom: 3
# Price: 950000
# Housetype: 881000
# Description: 2-Storey
# Bedroom: 3
# Price: 881000
# Housetype: 980000
# Description: Bungalow
# Bedroom: 3
# Price: 980000
# Housetype: 953000
# Description: Bungalow
# Bedroom: 3
# Price: 953000
# Housetype: 1380000
# Description: 2-Storey
# Bedroom: 4
# Price: 1380000
# Housetype: 1210000
# Description: 2-Storey
# Bedroom: 3
# Price: 1210000
# Housetype: 1151000
# Description: Bungaloft
# Bedroom: 3
# Price: 1151000
# Housetype: None
# Description: 2-Storey
# Bedroom: 3
# Price: None
# Housetype: 998000
# Description: 2-Storey
# ...
